# %% [markdown]
# # Using for loop, given a list of number find the largest

# %%
l = [1,100, 1000, 20, 25, 20000, 500, 400, 10001]
largest = l[0]
###Write code here to find the largest - 4lines
for i in l:
    if (i > largest):
        largest = i
###Write code here to find the largest - 4lines
print (largest)
